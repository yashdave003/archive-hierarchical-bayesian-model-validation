# %%
# assign directory
import os
BRANDON = '/Users/brandonmarks/Desktop/Research Materials/hierarchical-bayesian-model-validation/'
YASH = '/Users/yashd/Desktop/hierarchical-bayesian-model-validation/'

ROOT_DIR = BRANDON
data_dir = ROOT_DIR + 'raw-data/toy-syntheticMRI-2D/axial-slice'
# iterate over files in that directory
file_list = [os.path.join(data_dir, filename) for filename in os.listdir(data_dir) if filename != ".DS_Store"]
file_names = os.listdir(data_dir)

# %%
from PIL import ImageFilter
from PIL.ExifTags import TAGS
import rembg
os.chdir(ROOT_DIR + "testing-framework/")
from utilities import *
from plot_utilities import *
os.chdir(ROOT_DIR + "dataset-preparation/")
from transform_utilities import *

# %%
coeffs, mags = convert_fourier_list(data_dir, c = 3)
real_data = np.real(coeffs)
imag_data = np.imag(coeffs)

# %%
n= len(real_data)
n
# Out:
# 24420000

# %%
for i in range(10):
    twoSampleComparisonPlots(real_data[n//10 * i: n//10 * (i+1)], imag_data[n//10 * i: n//10 * (i+1)], samp1name="Real", samp2name="Imaginary")

# %%
n = len(file_list)
converted_003 = convert_to_fourier_basis(data_dir, "Gray", threshold =0.03, presplit= 2, max_depth = 9)
converted_003["number_of_coefficents"] = converted_003["data"].apply(lambda x:len(x))/(2 *n)
converted_003 = converted_003[converted_003["unique_magnitudes"] > 0]
converted_003
# Out:
# Both Endpoints Are The Same 0.0 and 0.0 Recursion Depth of 9
# Both Endpoints Are The Same 0.0027100271002710027 and 0.0027100271002710027 Recursion Depth of 9
# Both Endpoints Are The Same 0.003787878787878788 and 0.003787878787878788 Recursion Depth of 9
# Recursion Depth Exceeded Endpoints are 0.004657496387101694 and 0.005420054200542005
# Both Endpoints Are The Same 0.006612489187021414 and 0.006612489187021414 Recursion Depth of 9
# Recursion Depth Exceeded Endpoints are 0.007575757575757576 and 0.008130081300813007
# Recursion Depth Exceeded Endpoints are 0.008969183221982445 and 0.009314992774203388
# Both Endpoints Are The Same 0.01084010840108401 and 0.01084010840108401 Recursion Depth of 9
# Recursion Depth Exceeded Endpoints are 0.011112620069294083 and 0.011682314765882742
# Recursion Depth Exceeded Endpoints are 0.012590044437640866 and 0.013550135501355014
# Recursion Depth Exceeded Endpoints are 0.013972489161305082 and 0.014069619675625335
# Recursion Depth Exceeded Endpoints are 0.015151515151515152 and 0.016260162601626015
# Recursion Depth Exceeded Endpoints are 0.016695535736926184 and 0.01768441131364118
# Recursion Depth Exceeded Endpoints are 0.01793836644396489 and 0.01913229964420783
# Recursion Depth Exceeded Endpoints are 0.01934466652691697 and 0.02042694789175828
# Recursion Depth Exceeded Endpoints are 0.020610649304410117 and 0.021822204126503906
# Recursion Depth Exceeded Endpoints are 0.022008630722983896 and 0.02328748193550847
# Recursion Depth Exceeded Endpoints are 0.023364629531765484 and 0.02468262594077312
# Recursion Depth Exceeded Endpoints are 0.024961841491021233 and 0.025539696561766592
# Recursion Depth Exceeded Endpoints are 0.026449956748085656 and 0.02736371162930914
# Recursion Depth Exceeded Endpoints are 0.02773358040046887 and 0.028787713410074106
# Recursion Depth Exceeded Endpoints are 0.02938633900004022 and 0.03004998999501092
# Recursion Depth Exceeded Endpoints are 0.030303030303030304 and 0.03140956424735694
# Recursion Depth Exceeded Endpoints are 0.03190276013754222 and 0.03274018291086553
# Recursion Depth Exceeded Endpoints are 0.035751108274742094 and 0.03701769785974419
# Recursion Depth Exceeded Endpoints are 0.03725997109681355 and 0.038350308145006395
# Recursion Depth Exceeded Endpoints are 0.03868933305383394 and 0.0398962044919067
# Recursion Depth Exceeded Endpoints are 0.039998479548876635 and 0.041221298608820234
# Recursion Depth Exceeded Endpoints are 0.041350304131800304 and 0.04250797005897797
# Recursion Depth Exceeded Endpoints are 0.04305367651267849 and 0.04381457843248287
# Recursion Depth Exceeded Endpoints are 0.04401726144596779 and 0.045286244662515594
# Recursion Depth Exceeded Endpoints are 0.045454545454545456 and 0.04668917917870682
# Recursion Depth Exceeded Endpoints are 0.04672925906353097 and 0.04745123371356851
# Recursion Depth Exceeded Endpoints are 0.048202245219022756 and 0.04936525188154624
# Recursion Depth Exceeded Endpoints are 0.052328162907495694 and 0.05330656645313577
# Recursion Depth Exceeded Endpoints are 0.05361226501902383 and 0.05486322783056907
# Recursion Depth Exceeded Endpoints are 0.054951800178805375 and 0.056207126182462104
# Recursion Depth Exceeded Endpoints are 0.05627847870250134 and 0.05757542682014821
# Recursion Depth Exceeded Endpoints are 0.05784300938982359 and 0.05901176066341488
# Recursion Depth Exceeded Endpoints are 0.05909905813932473 and 0.060338644445767475
# Recursion Depth Exceeded Endpoints are 0.06054745303232202 and 0.06156786931779225
# Recursion Depth Exceeded Endpoints are 0.061753244512673215 and 0.06295022218820434
# Recursion Depth Exceeded Endpoints are 0.06335802106401747 and 0.06447547224704919
# Recursion Depth Exceeded Endpoints are 0.06462164047907754 and 0.06580414578714187
# Recursion Depth Exceeded Endpoints are 0.06877983813233905 and 0.07010187091380544
# Recursion Depth Exceeded Endpoints are 0.07023773533630279 and 0.07146106092304305
# Recursion Depth Exceeded Endpoints are 0.0769598366472403 and 0.0782745231628148
# Recursion Depth Exceeded Endpoints are 0.07852391061839235 and 0.07959160499529569
# [0.00135501 0.00271003 0.00460397 0.00542005 0.00737129 0.0087263
#  0.00990465 0.0109111  0.01233138 0.01368639 0.01511633 0.01646741
#  0.01791392 0.01925887 0.02058344 0.02190729 0.02334563 0.02468617
#  0.02616278 0.02737441 0.02889179 0.03023688 0.03152161 0.0329116
#  0.03570638 0.03705071 0.03843851 0.03995532 0.04125196 0.04258244
#  0.04389651 0.04535322 0.04669126 0.04804726 0.04944024 0.05220152
#  0.0535957  0.0549107  0.05626361 0.05764522 0.05909083 0.06037797
#  0.06174884 0.0631758  0.06458108 0.06590514 0.06874348 0.07012045
#  0.07146442 0.07690945 0.07827572 0.07965916 0.08237643 0.08791448
#  0.098984   0.10994455 0.11534267 0.120902   0.1264416  0.1291814
#  0.13193174 0.14289659 0.15390812 0.16487076 0.1758586  0.18686002
#  0.19784517 0.20883772 0.21983555 0.23082741 0.24181765 0.25284959
#  0.26380017 0.285788   0.30777945 0.35173616 0.43966689 0.48363025
#  0.50562631 0.51661583 0.5276064 ]
#     band channel                            magnitude_endpoints  \
# 0      1    Gray                                     (0.0, 0.0)
# 2      3    Gray  (0.0027100271002710027, 0.003787878787878788)
# 3      4    Gray   (0.004657496387101694, 0.004657496387101694)
# 4      5    Gray   (0.005420054200542005, 0.006612489187021414)
# 5      6    Gray   (0.007575757575757576, 0.008130081300813007)
# ..   ...     ...                                            ...
# 76    77    Gray      (0.3517404918906334, 0.43961825973984214)
# 77    78    Gray      (0.4396672099766883, 0.48361666317292423)
# 78    79    Gray        (0.4836593398154642, 0.505620866026968)
# 79    80    Gray       (0.5056383854393758, 0.5165983652449765)
# 80    81    Gray       (0.5166288755880262, 0.5275932800266083)
#
#     unique_magnitudes                                               data  \
# 0                   1  [3710897.0, 3892908.0, 3690392.0, 4036826.0, 4...
# 2                   2  [-853247.4650721303, -832898.1169039737, -8675...
# 3                   1  [138763.7854226057, 76244.15831164617, 35242.5...
# 4                   2  [-263062.47936831694, -278753.91593519563, -32...
# 5                   3  [-33050.25250593864, -114934.75436404074, -181...
# ..                ...                                                ...
# 76               5357  [-615.3411308251236, 126.9222653919529, 1120.6...
# 77               3120  [1401.9135193593493, 1757.341841152941, -220.7...
# 78               1599  [-9.620413548346644, -315.6828723283875, 230.3...
# 79                620  [-51.96594997091063, -28.807430461299973, 152....
# 80                545  [31.539210399442375, 179.610263444221, 204.780...
#
#     number_of_coefficents
# 0                     1.0
# 2                     2.0
# 3                     1.0
# 4                     2.0
# 5                     3.0
# ..                    ...
# 76                 5358.0
# 77                 3120.0
# 78                 1599.0
# 79                  620.0
# 80                  545.0
#
# [80 rows x 6 columns]

# %%
filtered_003 = converted_003[converted_003["magnitude_endpoints"].apply(lambda x: x[0] > 0.07959160499529569)]
filtered_003
# Out:
#     band channel                         magnitude_endpoints  \
# 52    53    Gray  (0.07972989606402223, 0.08235849244053915)
# 53    54    Gray   (0.0823939230146883, 0.08779301539198031)
# 54    55    Gray  (0.08803452289193558, 0.09884225606762043)
# 55    56    Gray   (0.09907963126309471, 0.1099334748657493)
# 56    57    Gray  (0.10994941180570059, 0.11525007492231071)
# 57    58    Gray  (0.11535973017885467, 0.12073592096227644)
# 58    59    Gray  (0.12102861999208522, 0.12643127816061167)
# 59    60    Gray  (0.12650821646898164, 0.12916102953803546)
# 60    61    Gray   (0.12923860293897765, 0.1318545844855219)
# 61    62    Gray  (0.13198729333572978, 0.14282252940166754)
# 62    63    Gray   (0.1429221218460861, 0.15380587726521164)
# 63    64    Gray  (0.15391257506094477, 0.16485793174588767)
# 64    65    Gray   (0.16488519443528094, 0.1758289501076173)
# 65    66    Gray  (0.17588314094441154, 0.18678470539117376)
# 66    67    Gray   (0.18686371573312344, 0.1978368895693265)
# 67    68    Gray   (0.1978682381576963, 0.20880955887910826)
# 68    69    Gray   (0.20894751248492868, 0.2198072007152215)
# 69    70    Gray  (0.21984734866718098, 0.23079936547726188)
# 70    71    Gray   (0.23085006421865067, 0.2418074662875402)
# 71    72    Gray     (0.2419112212536917, 0.252810185424636)
# 72    73    Gray   (0.25286255632122334, 0.2637879522773151)
# 73    74    Gray   (0.26384170451295147, 0.2857855404988369)
# 74    75    Gray    (0.2857975316428743, 0.3077342886269548)
# 75    76    Gray   (0.30778609567658405, 0.3517171955514112)
# 76    77    Gray   (0.3517404918906334, 0.43961825973984214)
# 77    78    Gray   (0.4396672099766883, 0.48361666317292423)
# 78    79    Gray     (0.4836593398154642, 0.505620866026968)
# 79    80    Gray    (0.5056383854393758, 0.5165983652449765)
# 80    81    Gray    (0.5166288755880262, 0.5275932800266083)
#
#     unique_magnitudes                                               data  \
# 52                 32  [14117.606365130701, 20268.192794760955, 6742....
# 53                 74  [-14378.922276001584, 1426.5127218583457, -189...
# 54                162  [20725.217727505566, -9611.640465205013, -2193...
# 55                176  [-26195.984947417557, -28606.159265315135, -10...
# 56                100  [-11307.720070136349, 6615.850059419533, -7056...
# 57                 96  [-2149.5034462041563, 6423.645777509517, 11433...
# 58                113  [18327.88431030003, -15070.007521163949, 9585....
# 59                 53  [12204.441232303974, 3869.7668676348803, -9797...
# 60                 51  [-1772.1835154037017, -1479.2205994669991, -88...
# 61                234  [6719.168304487492, -1304.3098444603918, 15504...
# 62                255  [-6707.109849961938, 11445.82296678316, -7061....
# 63                274  [-7136.906231088228, 3118.6792333363064, 1918....
# 64                287  [-4457.495839178909, -2411.473948142215, 10895...
# 65                309  [624.8498700509282, -34.763116509729116, 1224....
# 66                329  [2141.2269524324543, -1123.7001181512978, 3228...
# 67                347  [-556.891556066013, -4214.92138728198, 351.485...
# 68                363  [-1033.8020467808524, -1848.2232438130204, 693...
# 69                379  [228.33070590461978, 2933.333848212781, 7013.0...
# 70                404  [193.58680160496812, 2260.3788121509015, -3430...
# 71                419  [1533.6662795983423, -790.8995533639566, -1378...
# 72                438  [958.3565779845471, 1950.1417282600382, -5172....
# 73                934  [-563.1047230225045, -867.4049196626734, -179....
# 74               1006  [-286.4511016807308, 607.5750354587876, -811.4...
# 75               2227  [-766.7750456864422, -583.7635300564328, 3865....
# 76               5357  [-615.3411308251236, 126.9222653919529, 1120.6...
# 77               3120  [1401.9135193593493, 1757.341841152941, -220.7...
# 78               1599  [-9.620413548346644, -315.6828723283875, 230.3...
# 79                620  [-51.96594997091063, -28.807430461299973, 152....
# 80                545  [31.539210399442375, 179.610263444221, 204.780...
#
#     number_of_coefficents
# 52                   32.0
# 53                   74.0
# 54                  162.0
# 55                  176.0
# 56                  100.0
# 57                   96.0
# 58                  113.0
# 59                   53.0
# 60                   51.0
# 61                  234.0
# 62                  255.0
# 63                  274.0
# 64                  287.0
# 65                  309.0
# 66                  329.0
# 67                  347.0
# 68                  363.0
# 69                  379.0
# 70                  404.0
# 71                  419.0
# 72                  438.0
# 73                  934.0
# 74                 1006.0
# 75                 2227.0
# 76                 5358.0
# 77                 3120.0
# 78                 1599.0
# 79                  620.0
# 80                  545.0

# %%
filtered_003["magnitude_length"] = filtered_003["magnitude_endpoints"].apply(lambda x: x[1] - x[0])
x = np.asfarray(filtered_003["band"].to_numpy())
y = np.asfarray(filtered_003["magnitude_endpoints"].apply(lambda x: x[1]).to_numpy())
logy = np.log(y)
plt.plot(x, logy)
print(np.poly1d(np.polyfit(x, logy, 1)))
plt.plot(x, np.poly1d(np.polyfit(x, logy, 1))(x))
np.exp(np.polyfit(x, logy, 1)[0])
# Out:
#
# 0.06453 x - 5.917
# /var/folders/0c/5hhs4r6n7pnc4jcl295d7j_c0000gn/T/ipykernel_7890/3674162930.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_003["magnitude_length"] = filtered_003["magnitude_endpoints"].apply(lambda x: x[1] - x[0])
# 1.066661533853128

# %%
splits = getSplits(0.07959160499529569,0.5275932800266083, 1.066)
splits
# Out:
# [0.07959160499529569,
#  0.08484465092498521,
#  0.09044439788603424,
#  0.0964137281465125,
#  0.10277703420418233,
#  0.10956031846165837,
#  0.11679129948012783,
#  0.12449952524581627,
#  0.13271649391204016,
#  0.14147578251023482,
#  0.15081318415591033,
#  0.1607668543102004,
#  0.17137746669467363,
#  0.1826883794965221,
#  0.1947458125432926,
#  0.20759903617114991,
#  0.22130057255844582,
#  0.23590641034730325,
#  0.2514762334302253,
#  0.26807366483662015,
#  0.2857665267158371,
#  0.30462711747908233,
#  0.3247325072327018,
#  0.34616485271006014,
#  0.36901173298892415,
#  0.39336650736619316,
#  0.41932869685236196,
#  0.44700439084461785,
#  0.47650668064036267,
#  0.5079561215626266]

# %%
converted_with_splits = convert_to_fourier_basis(data_dir, "Gray", split_list = splits)
converted_with_splits
# Out:
# [0.0795916  0.08484465 0.0904444  0.09641373 0.10277703 0.10956032
#  0.1167913  0.12449953 0.13271649 0.14147578 0.15081318 0.16076685
#  0.17137747 0.18268838 0.19474581 0.20759904 0.22130057 0.23590641
#  0.25147623 0.26807366 0.28576653 0.30462712 0.32473251 0.34616485
#  0.36901173 0.39336651 0.4193287  0.44700439 0.47650668 0.50795612]
#     band channel                         magnitude_endpoints  \
# 0      1    Gray                  (0.0, 0.07958702332846287)
# 1      2    Gray  (0.07959160499529569, 0.08480974076355595)
# 2      3    Gray  (0.08490487225286758, 0.09036685796280594)
# 3      4    Gray  (0.09045831030085763, 0.09640449043804551)
# 4      5    Gray  (0.09655068286264279, 0.10275098804461226)
# 5      6    Gray  (0.10281441003134774, 0.10946815448505284)
# 6      7    Gray  (0.10972645566113814, 0.11677715783379244)
# 7      8    Gray   (0.11681379526292049, 0.1244151854206075)
# 8      9    Gray  (0.12466124661246612, 0.13268964582609089)
# 9     10    Gray   (0.1327561602377673, 0.14147529050912944)
# 10    11    Gray  (0.14149438077661972, 0.15077425426887275)
# 11    12    Gray   (0.15087355418460952, 0.1607599803071249)
# 12    13    Gray  (0.16081970600525025, 0.17134479148110804)
# 13    14    Gray   (0.1714026962879795, 0.18261227873833474)
# 14    15    Gray  (0.18271215949568376, 0.19471543049705517)
# 15    16    Gray  (0.19475767097591018, 0.20759608066932905)
# 16    17    Gray  (0.20763459544147186, 0.22124609409098586)
# 17    18    Gray  (0.22135101429103943, 0.23590020632567435)
# 18    19    Gray   (0.23596358919177746, 0.2514645595077373)
# 19    20    Gray    (0.2514806648499206, 0.2680689668890824)
# 20    21    Gray  (0.26807753711412957, 0.28575052155341124)
# 21    22    Gray    (0.2857855404988369, 0.3046116392472209)
# 22    23    Gray    (0.3046495161177802, 0.3247101518252371)
# 23    24    Gray   (0.3247332828977356, 0.34616068998615407)
# 24    25    Gray     (0.346175714215241, 0.3689761522779922)
# 25    26    Gray    (0.3690317899132036, 0.3933441034971884)
# 26    27    Gray    (0.3934005377051688, 0.4193123530959245)
# 27    28    Gray    (0.4193305009713019, 0.4470025581545586)
# 28    29    Gray   (0.4470051263937024, 0.47650347806378557)
# 29    30    Gray     (0.4765241716302995, 0.507954893202724)
#
#     unique_magnitudes                                               data
# 0                 512  [3710897.0, 3892908.0, 3690392.0, 4036826.0, 4...
# 1                  68  [14650.11723414603, 2276.965665419626, 2811.44...
# 2                  71  [13213.367343535561, 12087.876639120928, 10571...
# 3                  92  [18080.957101150885, -15767.449784966255, -552...
# 4                  98  [-5040.489743227421, 2042.7003602301907, -9498...
# 5                 111  [-6549.319785609915, -1797.011083839076, 18465...
# 6                 127  [-3491.111466756942, -2612.4092296367435, -139...
# 7                 145  [-791.4995526980565, 11411.778377775456, -3245...
# 8                 164  [490.0322174333878, 4302.86072935264, -3257.48...
# 9                 191  [-7277.561978296133, -1166.1829033653357, 560....
# 10                209  [3644.0105720820143, -10378.036272976868, -148...
# 11                240  [-60.84017976032874, 7181.213409674323, -12274...
# 12                276  [5812.702172233569, -4685.234057118677, 5394.9...
# 13                308  [3186.1525682449974, -26.481169010721032, 6306...
# 14                352  [-1471.1558319158262, 3345.2382477293177, -372...
# 15                400  [-987.0718825153358, 3299.9463296957188, -3373...
# 16                457  [855.5316106867531, -508.6184238208167, 2540.0...
# 17                512  [-729.1878340912743, -1337.519788524587, -158....
# 18                585  [-95.9176025638148, -1261.7696563123425, 1145....
# 19                663  [506.9407940756408, 5.372187584283296, 530.162...
# 20                760  [-935.1826867992414, 218.8629469342602, 2927.0...
# 21                861  [621.6641822516483, 1468.5395836505618, 102.41...
# 22                968  [-296.989060905717, 494.18292228430454, -1770....
# 23               1108  [-450.3974538494902, 12.886979308162182, -1239...
# 24               1261  [-83.79366622672117, 318.96786679895206, 370.9...
# 25               1424  [219.64812339748323, -841.014915477213, -248.6...
# 26               1624  [-222.61001171828804, -130.4292382721893, 490....
# 27               1833  [87.09795075128143, 10.355946899688519, 227.83...
# 28               2101  [233.5778041075993, -292.95449958662005, 302.7...
# 29               2270  [30.215713566270534, 113.98396763083163, -663....
